# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
aapl_df = pd.DataFrame(yf.download("AAPL", start="2015-03-24", end="2020-03-24"))

aapl_df.dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-03-24  28.293383  28.594873  28.264349  28.413980  131369200
# 2015-03-25  27.554167  28.322415  27.554167  28.259883  206620800
# 2015-03-26  27.746233  27.889163  27.379976  27.415709  190291600
# 2015-03-27  27.525133  27.848958  27.449203  27.819926  158184800
# 2015-03-30  28.221916  28.228616  27.692629  27.703796  188398800
# ...               ...        ...        ...        ...        ...
# 2020-03-17  61.363815  62.516537  57.854675  60.065481  324056000
# 2020-03-18  59.861633  60.669755  57.544048  58.187150  300233600
# 2020-03-19  59.402977  61.358970  58.876364  60.036369  271857200
# 2020-03-20  55.631737  61.113855  55.330813  59.985395  401693200
# 2020-03-23  54.449890  55.452156  51.595986  55.350231  336752800
#
# [1259 rows x 5 columns]

# %%
aapl_df['ema_short'] = aapl_df['Close'].ewm(span=5, adjust=False).mean()
aapl_df['ema_long'] = aapl_df['Close'].ewm(span=20, adjust=False).mean()

# %%
aapl_df['bullish'] = 0.0
aapl_df['bullish'] = np.where(aapl_df['ema_short'] > aapl_df['ema_long'], 1.0, 0.0)
aapl_df['crossover'] = aapl_df['bullish'].diff()

# %%
aapl_df['Signal'] = 0.0
aapl_df.loc[aapl_df['crossover'] == 1, 'Signal'] = 1
aapl_df.loc[aapl_df['crossover'] == -1, 'Signal'] = -1

# %%
aapl_df.head(20)
# Out:
# Price           Close       High        Low       Open     Volume  ema_short  \
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-03-24  28.293383  28.594873  28.264349  28.413980  131369200  28.293383
# 2015-03-25  27.554167  28.322415  27.554167  28.259883  206620800  28.046977
# 2015-03-26  27.746233  27.889163  27.379976  27.415709  190291600  27.946729
# 2015-03-27  27.525133  27.848958  27.449203  27.819926  158184800  27.806197
# 2015-03-30  28.221916  28.228616  27.692629  27.703796  188398800  27.944770
# 2015-03-31  27.788664  28.248718  27.773031  28.159387  168362400  27.892735
# 2015-04-01  27.748457  27.942753  27.491630  27.875754  162485600  27.844642
# 2015-04-02  27.987421  28.041019  27.735061  27.922656  128880400  27.892235
# 2015-04-06  28.440779  28.476512  27.766330  27.797596  148776000  28.075083
# 2015-04-07  28.141518  28.612737  28.134818  28.505541  140049200  28.097228
# 2015-04-08  28.049957  28.228620  27.909261  28.105789  149316800  28.081471
# 2015-04-09  28.264347  28.268815  27.840026  28.105785  129936000  28.142430
# 2015-04-10  28.384947  28.409513  27.974025  28.128120  160752000  28.223269
# 2015-04-13  28.329117  28.713242  28.275519  28.668574  145460400  28.258551
# 2015-04-14  28.206285  28.427379  28.119188  28.362614  102098400  28.241129
# 2015-04-15  28.313477  28.391641  28.141515  28.230846  115881600  28.265245
# 2015-04-16  28.177254  28.384949  28.163855  28.201820  113476000  28.235915
# 2015-04-17  27.860130  28.170556  27.795365  28.038793  207828000  28.110653
# 2015-04-20  28.496614  28.612744  27.953928  28.043259  188217200  28.239307
# 2015-04-21  28.342522  28.630613  28.288922  28.608282  129740400  28.273712
#
# Price        ema_long bullish crossover Signal
# Ticker
# Date
# 2015-03-24  28.293383     0.0       NaN    0.0
# 2015-03-25  28.222981     0.0       0.0    0.0
# 2015-03-26  28.177577     0.0       0.0    0.0
# 2015-03-27  28.115439     0.0       0.0    0.0
# 2015-03-30  28.125580     0.0       0.0    0.0
# 2015-03-31  28.093493     0.0       0.0    0.0
# 2015-04-01  28.060632     0.0       0.0    0.0
# 2015-04-02  28.053660     0.0       0.0    0.0
# 2015-04-06  28.090528     0.0       0.0    0.0
# 2015-04-07  28.095384     1.0       1.0    1.0
# 2015-04-08  28.091058     0.0      -1.0   -1.0
# 2015-04-09  28.107562     1.0       1.0    1.0
# 2015-04-10  28.133979     1.0       0.0    0.0
# 2015-04-13  28.152564     1.0       0.0    0.0
# 2015-04-14  28.157680     1.0       0.0    0.0
# 2015-04-15  28.172518     1.0       0.0    0.0
# 2015-04-16  28.172969     1.0       0.0    0.0
# 2015-04-17  28.143175     0.0      -1.0   -1.0
# 2015-04-20  28.176836     1.0       1.0    1.0
# 2015-04-21  28.192615     1.0       0.0    0.0

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(111, ylabel='Price in $')

aapl_df['Close'].plot(ax=ax1, color='b', lw=2.)
aapl_df['ema_short'].plot(ax=ax1, color='r', lw=2.)
aapl_df['ema_long'].plot(ax=ax1, color='g', lw=2.)

ax1.plot(aapl_df.loc[aapl_df.positions == 1.0].index,
         aapl_df.Close[aapl_df.positions == 1.0],
         '^', markersize=10, color='g')
ax1.plot(aapl_df.loc[aapl_df.positions == -1.0].index,
         aapl_df.Close[aapl_df.positions == -1.0],
         'v', markersize=10, color='r')
plt.legend(['Close', 'EMA Short', 'EMA Long', 'Buy', 'Sell'])
plt.title('AAPL EMA Crossover')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-198-289ed875222d> in <cell line: 0>()
#       6 aapl_df['ema_long'].plot(ax=ax1, color='g', lw=2.)
#       7
# ----> 8 ax1.plot(aapl_df.loc[aapl_df.positions == 1.0].index,
#       9          aapl_df.Close[aapl_df.positions == 1.0],
#      10          '^', markersize=10, color='g')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'positions'

# %%
aapl_df['daily_return'] = aapl_df['Close'].pct_change().squeeze()
aapl_df.head()
# Out:
# Price           Close       High        Low       Open     Volume  ema_short  \
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-03-24  28.293383  28.594873  28.264349  28.413980  131369200  28.293383
# 2015-03-25  27.554167  28.322415  27.554167  28.259883  206620800  28.046977
# 2015-03-26  27.746233  27.889163  27.379976  27.415709  190291600  27.946729
# 2015-03-27  27.525133  27.848958  27.449203  27.819926  158184800  27.806197
# 2015-03-30  28.221916  28.228616  27.692629  27.703796  188398800  27.944770
#
# Price        ema_long bullish crossover Signal daily_return
# Ticker
# Date
# 2015-03-24  28.293383     0.0       NaN    0.0          NaN
# 2015-03-25  28.222981     0.0       0.0    0.0    -0.026127
# 2015-03-26  28.177577     0.0       0.0    0.0     0.006970
# 2015-03-27  28.115439     0.0       0.0    0.0    -0.007969
# 2015-03-30  28.125580     0.0       0.0    0.0     0.025314

# %%
aapl_df['daily_return'] = aapl_df['Close'].pct_change().squeeze()

# Calculate strategy returns by applying the signal from the previous day
aapl_df['strategy_return'] = aapl_df['Signal'] * aapl_df['Close'].pct_change().squeeze()

# Calculate cumulative strategy returns
aapl_df['cumulative_strategy_return'] = (1 + aapl_df['strategy_return']).cumprod()

# %%
aapl_df.tail(20)
# Out:
# Price           Close       High        Low       Open     Volume  ema_short  \
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-02-25  69.910980  73.417696  69.437761  73.034266  230673600  73.784095
# 2020-02-26  71.020012  72.289226  69.527537  69.534818  198054800  72.862734
# 2020-02-27  66.377548  69.406184  66.241649  68.217059  320605600  70.701005
# 2020-02-28  66.338722  67.564256  62.215609  62.431597  426510000  69.246911
# 2020-03-02  72.514938  73.153186  67.396837  68.503453  341397200  70.336253
# 2020-03-03  70.211899  73.774425  69.357664  73.694344  319475600  70.294802
# 2020-03-04  73.468643  73.628812  71.136501  71.939768  219178400  71.352749
# 2020-03-05  71.085548  72.694504  70.719101  71.716508  187572800  71.263682
# 2020-03-06  70.141510  70.575907  68.248617  68.435477  226176800  70.889625
# 2020-03-09  64.593872  67.486602  63.824576  64.006586  286744800  68.791041
# 2020-03-10  69.246025  69.512973  65.370441  67.256062  285290000  68.942702
# 2020-03-11  66.841080  68.246193  65.974714  67.316736  255598800  68.242161
# 2020-03-12  60.240211  65.523335  60.184396  62.111268  418474000  65.574845
# 2020-03-13  67.457481  67.930708  61.385652  64.283243  370732000  66.202390
# 2020-03-16  58.779289  62.873280  58.242967  58.716190  322423600  63.728023
# 2020-03-17  61.363815  62.516537  57.854675  60.065481  324056000  62.939954
# 2020-03-18  59.861633  60.669755  57.544048  58.187150  300233600  61.913847
# 2020-03-19  59.402977  61.358970  58.876364  60.036369  271857200  61.076890
# 2020-03-20  55.631737  61.113855  55.330813  59.985395  401693200  59.261839
# 2020-03-23  54.449890  55.452156  51.595986  55.350231  336752800  57.657856
#
# Price        ema_long bullish crossover Signal daily_return strategy_return  \
# Ticker
# Date
# 2020-02-25  76.050131     0.0       0.0    0.0    -0.033872            -0.0
# 2020-02-26  75.571072     0.0       0.0    0.0     0.015863             0.0
# 2020-02-27  74.695498     0.0       0.0    0.0    -0.065368            -0.0
# 2020-02-28  73.899615     0.0       0.0    0.0    -0.000585            -0.0
# 2020-03-02  73.767741     0.0       0.0    0.0     0.093101             0.0
# 2020-03-03  73.429089     0.0       0.0    0.0    -0.031760            -0.0
# 2020-03-04  73.432856     0.0       0.0    0.0     0.046385             0.0
# 2020-03-05  73.209303     0.0       0.0    0.0    -0.032437            -0.0
# 2020-03-06  72.917132     0.0       0.0    0.0    -0.013280            -0.0
# 2020-03-09  72.124441     0.0       0.0    0.0    -0.079092            -0.0
# 2020-03-10  71.850306     0.0       0.0    0.0     0.072022             0.0
# 2020-03-11  71.373237     0.0       0.0    0.0    -0.034730            -0.0
# 2020-03-12  70.312949     0.0       0.0    0.0    -0.098755            -0.0
# 2020-03-13  70.040999     0.0       0.0    0.0     0.119808             0.0
# 2020-03-16  68.968456     0.0       0.0    0.0    -0.128647            -0.0
# 2020-03-17  68.244204     0.0       0.0    0.0     0.043970             0.0
# 2020-03-18  67.445864     0.0       0.0    0.0    -0.024480            -0.0
# 2020-03-19  66.679875     0.0       0.0    0.0    -0.007662            -0.0
# 2020-03-20  65.627671     0.0       0.0    0.0    -0.063486            -0.0
# 2020-03-23  64.563121     0.0       0.0    0.0    -0.021244            -0.0
#
# Price      cumulative_strategy_return
# Ticker
# Date
# 2020-02-25                   2.659082
# 2020-02-26                   2.659082
# 2020-02-27                   2.659082
# 2020-02-28                   2.659082
# 2020-03-02                   2.659082
# 2020-03-03                   2.659082
# 2020-03-04                   2.659082
# 2020-03-05                   2.659082
# 2020-03-06                   2.659082
# 2020-03-09                   2.659082
# 2020-03-10                   2.659082
# 2020-03-11                   2.659082
# 2020-03-12                   2.659082
# 2020-03-13                   2.659082
# 2020-03-16                   2.659082
# 2020-03-17                   2.659082
# 2020-03-18                   2.659082
# 2020-03-19                   2.659082
# 2020-03-20                   2.659082
# 2020-03-23                   2.659082

# %%
aapl_df['cumulative_buy_hold'] = (1 + aapl_df['daily_return']).cumprod()

# Plot the cumulative returns
plt.figure(figsize=(12, 6))
plt.plot(aapl_df.index, aapl_df['cumulative_strategy_return'], label='Strategy Returns', linewidth=2)
plt.plot(aapl_df.index, aapl_df['cumulative_buy_hold'], label='Buy & Hold Returns', linestyle='--')
plt.title('Cumulative Returns: Strategy vs. Buy & Hold')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.legend()
plt.grid(True)
plt.show()

# %%
rsi_period = 14

aapl_df['Price Changes'] = aapl_df['Close'].diff()
aapl_df['Gain'] = np.where(aapl_df['Price Changes'] > 0, aapl_df['Price Changes'], 0)
aapl_df['Loss'] = np.where(aapl_df['Price Changes'] < 0, -aapl_df['Price Changes'], 0)

aapl_df['AvgGain'] = aapl_df['Gain'].rolling(window=rsi_period).mean()
aapl_df['AvgLoss'] = aapl_df['Loss'].rolling(window=rsi_period).mean()

import math
aapl_df['RS'] = aapl_df['AvgGain'] / (aapl_df['AvgLoss'] + 1 * math.exp(1) - 9)
aapl_df['RSI'] = 100 - (100 / (1 + aapl_df['RS']))
rsi =  aapl_df['RSI'].to_numpy().ravel()


aapl_df['RSISignal'] = 0.0
aapl_df.loc[(aapl_df['crossover'] == 1) & (rsi > 50), 'RSISignal'] = 1
aapl_df.loc[(aapl_df['crossover'] == -1) & (rsi < 50), 'RSISignal'] = -1

# %%
aapl_df['RSIstrategy_return'] = aapl_df['RSISignal'] * aapl_df['Close'].pct_change().squeeze()

# Calculate cumulative strategy returns
aapl_df['RSIcumulative_strategy_return'] = (1 + aapl_df['RSIstrategy_return']).cumprod()

# %%
# Plot the cumulative returns
plt.figure(figsize=(12, 6))
plt.plot(aapl_df.index, aapl_df['cumulative_strategy_return'], label='Strategy Returns', linewidth=2)
plt.plot(aapl_df.index, aapl_df['cumulative_buy_hold'], label='Buy & Hold Returns', linestyle='--')
plt.plot(aapl_df.index, aapl_df['RSIcumulative_strategy_return'], label='Strategy Returns w/ RSI', linestyle='--')

plt.title('Cumulative Returns: Strategy vs. Buy & Hold')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.legend()
plt.grid(True)
plt.show()

# %%
aapl_df.tail(5)
# Out:
# Price           Close       High        Low       Open     Volume  ema_short  \
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-03-17  61.363815  62.516537  57.854675  60.065481  324056000  62.939954
# 2020-03-18  59.861633  60.669755  57.544048  58.187150  300233600  61.913847
# 2020-03-19  59.402977  61.358970  58.876364  60.036369  271857200  61.076890
# 2020-03-20  55.631737  61.113855  55.330813  59.985395  401693200  59.261839
# 2020-03-23  54.449890  55.452156  51.595986  55.350231  336752800  57.657856
#
# Price        ema_long bullish crossover Signal daily_return strategy_return  \
# Ticker
# Date
# 2020-03-17  68.244204     0.0       0.0    0.0     0.043970             0.0
# 2020-03-18  67.445864     0.0       0.0    0.0    -0.024480            -0.0
# 2020-03-19  66.679875     0.0       0.0    0.0    -0.007662            -0.0
# 2020-03-20  65.627671     0.0       0.0    0.0    -0.063486            -0.0
# 2020-03-23  64.563121     0.0       0.0    0.0    -0.021244            -0.0
#
# Price      cumulative_strategy_return cumulative_buy_hold
# Ticker
# Date
# 2020-03-17                   2.659082            2.168840
# 2020-03-18                   2.659082            2.115747
# 2020-03-19                   2.659082            2.099536
# 2020-03-20                   2.659082            1.966246
# 2020-03-23                   2.659082            1.924474

# %% [markdown]
# Need to look at this more
